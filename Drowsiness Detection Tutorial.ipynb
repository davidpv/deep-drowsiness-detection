# %% [markdown]
# # 1. Install pre-requisites
# conda install -c "nvidia/label/cuda-11.7.0" cuda-toolkit
# conda install pytorch torchvision torchaudio pytorch-cuda=11.7 -c pytorch -c nvidia

# %%
# !git clone https: // github.com / ultralytics / yolov5.git

# %%
# !cd yolov5 & pip install -r requirements.txt

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
# OpenCV
import cv2

# %% [markdown]
# # 2. Load model

# %%
# import the pytorch ultralytics yolov5 model https://pytorch.org/hub/ultralytics_yolov5/
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')

# %% [markdown]
# # 3. Make Detections

# %% [markdown]
# Testing model with the COCO classnames https://gist.github.com/AruniRC/7b3dadd004da04c80198557db5da4bda

# %%
def detect(source):
    cap = cv2.VideoCapture(source)
    while cap.isOpened():
        ret, frame = cap.read()

        result = model(frame)

        cv2.imshow('YOLO', np.squeeze(result.render()))
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()

# %% [markdown]
# ### 3.1 Make Detections from an image:

# %%
img = 'samples/store.jpg'
results = model(img)
results.print()
results.show()

# %% [markdown]
# ### 3.2 Make Detections from a video:

# %%
detect("samples/traffic.mp4")

# %% [markdown]
# ### 3.3 Make Detections from a webcam:

# %%
detect(1)

# %% [markdown]
# # 5. Train a custom model

# %% [markdown]
# ### 5.1 Capture and use our custom images

# %%
import uuid
import os
import time

# %%
IMAGES_PATH = os.path.join('data', 'images')
labels = ['awake', 'drowsy']
number_imgs = 20

# %%
cap = cv2.VideoCapture(1)
for label in labels:

    time.sleep(5)

    for img_num in range(number_imgs):
        print('Collection images for {}'+ ': '+ str(img_num), format(label))
        ret, frame = cap.read()

        imgname = os.path.join(IMAGES_PATH, label + '.' + str(uuid.uuid1()) + '.jpg')

        cv2.imwrite(imgname, frame)
        cv2.imshow('Image collection', frame)
        time.sleep(1)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %%
# let's label the images
# https://github.com/heartexlabs/labelImg
! git clone https://github.com/heartexlabs/labelImg.git
# !pip install pyqt5 lxml --upgrade
# !cd labelImg && pyrcc5 -o libs/resources.py resources.qrc

# %% [markdown]
# # 6. label all images

# %% [markdown]
# # 7. re-train the model

# %%
# !cd yolov5 && python train.py --img 320 --batch 16 --epochs 500 --data dataset.yaml --weights yolov5s.pt --workers 2
# Out:
# requirements: C:\Users\david\Projects\SynologyDrive\Driver Drowsiness Detection\deep-drowsiness-detection\requirements.txt not found, check failed.
# train: weights=yolov5s.pt, cfg=, data=dataset.yaml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=500, batch_size=16, imgsz=320, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=2, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5
# fatal: cannot change to 'C:\Users\david\Projects\SynologyDrive\Driver': No such file or directory
# YOLOv5  2023-4-30 Python-3.9.16 torch-2.0.0 CUDA:0 (NVIDIA GeForce RTX 3080 Ti, 12288MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# ClearML: run 'pip install clearml' to automatically track, visualize and remotely train YOLOv5  in ClearML
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5  runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs\train', view at http://localhost:6006/
# Downloading https://ultralytics.com/assets/Arial.ttf to C:\Users\david\AppData\Roaming\Ultralytics\Arial.ttf...
#
#   0%|          | 0.00/755k [00:00<?, ?B/s]
#  44%|####4     | 336k/755k [00:00<00:00, 3.44MB/s]
# 100%|##########| 755k/755k [00:00<00:00, 4.37MB/s]
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5s.pt to yolov5s.pt...
#
#   0%|          | 0.00/14.1M [00:00<?, ?B/s]
#   7%|6         | 968k/14.1M [00:00<00:01, 9.50MB/s]
#  28%|##7       | 3.89M/14.1M [00:00<00:00, 19.5MB/s]
#  90%|######### | 12.8M/14.1M [00:00<00:00, 50.5MB/s]
# 100%|##########| 14.1M/14.1M [00:00<00:00, 44.9MB/s]
#
# Overriding model.yaml nc=80 with nc=17
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     59334  models.yolo.Detect                      [17, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 214 layers, 7065478 parameters, 7065478 gradients, 16.1 GFLOPs
#
# Transferred 343/349 items from yolov5s.pt
# AMP: checks passed
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
#
# train: Scanning C:\Users\david\Projects\SynologyDrive\Driver Drowsiness Detection\deep-drowsiness-detection\data\labels...:   0%|          | 0/40 [00:00<?, ?it/s]
# train: Scanning C:\Users\david\Projects\SynologyDrive\Driver Drowsiness Detection\deep-drowsiness-detection\data\labels... 1 images, 0 backgrounds, 0 corrupt:   2%|2         | 1/40 [00:06<04:05,  6.30s/it]
# train: Scanning C:\Users\david\Projects\SynologyDrive\Driver Drowsiness Detection\deep-drowsiness-detection\data\labels... 40 images, 0 backgrounds, 0 corrupt: 100%|##########| 40/40 [00:06<00:00,  6.33it/s]
# train: New cache created: C:\Users\david\Projects\SynologyDrive\Driver Drowsiness Detection\deep-drowsiness-detection\data\labels.cache
#
# val: Scanning C:\Users\david\Projects\SynologyDrive\Driver Drowsiness Detection\deep-drowsiness-detection\data\labels.cache... 40 images, 0 backgrounds, 0 corrupt: 100%|##########| 40/40 [00:00<?, ?it/s]
# val: Scanning C:\Users\david\Projects\SynologyDrive\Driver Drowsiness Detection\deep-drowsiness-detection\data\labels.cache... 40 images, 0 backgrounds, 0 corrupt: 100%|##########| 40/40 [00:00<?, ?it/s]
#
# AutoAnchor: 5.15 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset
# Plotting labels to runs\train\exp\labels.jpg...
# Image sizes 320 train, 320 val
# Using 2 dataloader workers
# Logging results to runs\train\exp
# Starting training for 500 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#       0/499     0.908G     0.1142    0.01681    0.07629         36        320:   0%|          | 0/3 [00:00<?, ?it/s]
#       0/499     0.908G     0.1142    0.01681    0.07629         36        320:  33%|###3      | 1/3 [00:00<00:01,  1.25it/s]
#       0/499      1.05G     0.1137    0.01618     0.0759         32        320:  33%|###3      | 1/3 [00:00<00:01,  1.25it/s]
#       0/499      1.05G     0.1137    0.01618     0.0759         32        320:  67%|######6   | 2/3 [00:00<00:00,  2.47it/s]
#       0/499      1.09G     0.1124    0.01578    0.07571         14        320:  67%|######6   | 2/3 [00:01<00:00,  2.47it/s]
#       0/499      1.09G     0.1124    0.01578    0.07571         14        320: 100%|##########| 3/3 [00:01<00:00,  2.93it/s]
#       0/499      1.09G     0.1124    0.01578    0.07571         14        320: 100%|##########| 3/3 [00:01<00:00,  2.51it/s]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/2 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  50%|#####     | 1/2 [00:00<00:00,  3.53it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|##########| 2/2 [00:00<00:00,  5.05it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|##########| 2/2 [00:00<00:00,  4.75it/s]
#                    all         40         40          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#       1/499      1.09G     0.1145    0.01645    0.07451         36        320:   0%|          | 0/3 [00:00<?, ?it/s]
#       1/499      1.09G      0.113    0.01514    0.07501         26        320:   0%|          | 0/3 [00:00<?, ?it/s]
#       1/499      1.09G      0.113    0.01514    0.07501         26        320:  67%|######6   | 2/3 [00:00<00:00, 11.91it/s]
#       1/499      1.09G     0.1106    0.01461    0.07348         12        320:  67%|######6   | 2/3 [00:00<00:00, 11.91it/s]
#       1/499      1.09G     0.1106    0.01461    0.07348         12        320: 100%|##########| 3/3 [00:00<00:00, 12.00it/s]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/2 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  50%|#####     | 1/2 [00:00<00:00,  5.02it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|##########| 2/2 [00:00<00:00,  7.21it/s]
#                    all         40         40          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#      27/499      1.11G    0.05994    0.01826    0.03276         35        320:   0%|          | 0/3 [00:00<?, ?it/s]
#      27/499      1.11G    0.06204    0.01824    0.03303         39        320:   0%|          | 0/3 [00:00<?, ?it/s]
#      27/499      1.11G    0.06204    0.01824    0.03303         39        320:  67%|######6   | 2/3 [00:00<00:00, 16.86it/s]
#      27/499      1.11G    0.06029    0.01724     0.0343         14        320:  67%|######6   | 2/3 [00:00<00:00, 16.86it/s]
#      27/499      1.11G    0.06029    0.01724     0.0343         14        320: 100%|##########| 3/3 [00:00<00:00, 15.13it/s]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/2 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  50%|#####     | 1/2 [00:00<00:00,  4.81it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|##########| 2/2 [00:00<00:00,  6.96it/s]
#                    all         40         40       0.48      0.975      0.618      0.136
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#      28/499      1.11G    0.08087    0.01377    0.03452         33        320:   0%|          | 0/3 [00:00<?, ?it/s]
#      28/499      1.11G    0.07918    0.01366    0.03388         30        320:   0%|          | 0/3 [00:00<?, ?it/s]
#      28/499      1.11G    0.07918    0.01366    0.03388         30        320:  67%|######6   | 2/3 [00:00<00:00, 18.40it/s]
#      28/499      1.11G    0.07793    0.01441    0.03429         20        320:  67%|######6   | 2/3 [00:00<00:00, 18.40it/s]
#      28/499      1.11G    0.07793    0.01441    0.03429         20        320: 100%|##########| 3/3 [00:00<00:00, 17.05it/s]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/2 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  50%|#####     | 1/2 [00:00<00:00,  4.33it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|##########| 2/2 [00:00<00:00,  6.63it/s]
#                    all         40         40       0.48      0.975      0.618      0.136
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#      29/499      1.11G     0.0738    0.01586    0.03364         36        320:   0%|          | 0/3 [00:00<?, ?it/s]
#      29/499      1.11G    0.07001    0.01587    0.03363         36        320:   0%|          | 0/3 [00:00<?, ?it/s]
#      29/499      1.11G    0.07001    0.01587    0.03363         36        320:  67%|######6   | 2/3 [00:00<00:00, 14.37it/s]
#      29/499      1.11G    0.06928    0.01541     0.0335         18        320:  67%|######6   | 2/3 [00:00<00:00, 14.37it/s]
#      29/499      1.11G    0.06928    0.01541     0.0335         18        320: 100%|##########| 3/3 [00:00<00:00, 13.58it/s]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/2 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  50%|#####     | 1/2 [00:00<00:00,  4.14it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|##########| 2/2 [00:00<00:00,  6.32it/s]
#                    all         40         40      0.488      0.975      0.621      0.163
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#      30/499      1.11G    0.06648    0.01566    0.03287         35        320:   0%|          | 0/3 [00:00<?, ?it/s]
#      30/499      1.11G    0.06815    0.01482    0.03337         28        320:   0%|          | 0/3 [00:00<?, ?it/s]
#      30/499      1.11G    0.06815    0.01482    0.03337         28        320:  67%|######6   | 2/3 [00:00<00:00, 14.20it/s]
#      30/499      1.11G    0.06795     0.0147    0.03386         16        320:  67%|######6   | 2/3 [00:00<00:00, 14.20it/s]
#      30/499      1.11G    0.06795     0.0147    0.03386         16        320: 100%|##########| 3/3 [00:00<00:00, 14.49it/s]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/2 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  50%|#####     | 1/2 [00:00<00:00,  4.03it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|##########| 2/2 [00:00<00:00,  6.16it/s]
#                    all         40         40      0.498      0.941      0.628      0.427
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#      31/499      1.11G    0.06804    0.01432    0.03585         31        320:   0%|          | 0/3 [00:00<?, ?it/s]
#      31/499      1.11G    0.06753    0.01501    0.03501         34        320:   0%|          | 0/3 [00:00<?, ?it/s]
#      31/499      1.11G    0.06753    0.01501    0.03501         34        320:  67%|######6   | 2/3 [00:00<00:00, 14.23it/s]
#      31/499      1.11G    0.06708    0.01515    0.03479         17        320:  67%|######6   | 2/3 [00:00<00:00, 14.23it/s]
#      31/499      1.11G    0.06708    0.01515    0.03479         17        320: 100%|##########| 3/3 [00:00<00:00, 13.13it/s]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/2 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  50%|#####     | 1/2 [00:00<00:00,  3.95it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|##########| 2/2 [00:00<00:00,  5.83it/s]
#                    all         40         40      0.413      0.825      0.513      0.191
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#      32/499      1.11G    0.06384    0.01589    0.03391         32        320:   0%|          | 0/3 [00:00<?, ?it/s]
#      32/499      1.11G    0.06798    0.01617    0.03351         40        320:   0%|          | 0/3 [00:00<?, ?it/s]
#      32/499      1.11G    0.06798    0.01617    0.03351         40        320:  67%|######6   | 2/3 [00:00<00:00, 14.58it/s]
#      32/499      1.11G    0.06902    0.01727    0.03358         21        320:  67%|######6   | 2/3 [00:00<00:00, 14.58it/s]
#      32/499      1.11G    0.06902    0.01727    0.03358         21        320: 100%|##########| 3/3 [00:00<00:00, 15.36it/s]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/2 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  50%|#####     | 1/2 [00:00<00:00,  4.19it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|##########| 2/2 [00:00<00:00,  6.44it/s]
# ...
#                    all         40         40      0.997          1      0.995      0.916
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#     488/499      1.11G     0.0118   0.004965   0.003566         28        320:   0%|          | 0/3 [00:00<?, ?it/s]
#     488/499      1.11G     0.0124    0.00448   0.003315         28        320:   0%|          | 0/3 [00:00<?, ?it/s]
#     488/499      1.11G     0.0124    0.00448   0.003315         28        320:  67%|######6   | 2/3 [00:00<00:00, 13.46it/s]
#     488/499      1.11G    0.01186   0.005139   0.003225         18        320:  67%|######6   | 2/3 [00:00<00:00, 13.46it/s]
#     488/499      1.11G    0.01186   0.005139   0.003225         18        320: 100%|##########| 3/3 [00:00<00:00, 13.75it/s]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/2 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  50%|#####     | 1/2 [00:00<00:00,  4.06it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|##########| 2/2 [00:00<00:00,  6.26it/s]
#                    all         40         40      0.997          1      0.995      0.916
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#     489/499      1.11G    0.01147    0.00486   0.002692         29        320:   0%|          | 0/3 [00:00<?, ?it/s]
#     489/499      1.11G    0.01147    0.00486   0.002692         29        320:  33%|###3      | 1/3 [00:00<00:00,  6.82it/s]
#     489/499      1.11G    0.01133   0.005211   0.002722         33        320:  33%|###3      | 1/3 [00:00<00:00,  6.82it/s]
#     489/499      1.11G    0.01133   0.005211   0.002722         33        320:  67%|######6   | 2/3 [00:00<00:00,  8.03it/s]
#     489/499      1.11G    0.01086   0.005146   0.002378         15        320:  67%|######6   | 2/3 [00:00<00:00,  8.03it/s]
#     489/499      1.11G    0.01086   0.005146   0.002378         15        320: 100%|##########| 3/3 [00:00<00:00,  9.30it/s]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/2 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  50%|#####     | 1/2 [00:00<00:00,  4.10it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|##########| 2/2 [00:00<00:00,  6.32it/s]
#                    all         40         40      0.997          1      0.995      0.916
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#     490/499      1.11G    0.01345   0.004396   0.009502         29        320:   0%|          | 0/3 [00:00<?, ?it/s]
#     490/499      1.11G    0.01355    0.00533   0.008258         34        320:   0%|          | 0/3 [00:00<?, ?it/s]
#     490/499      1.11G    0.01355    0.00533   0.008258         34        320:  67%|######6   | 2/3 [00:00<00:00, 11.70it/s]
#     490/499      1.11G    0.01338   0.005963   0.006811         18        320:  67%|######6   | 2/3 [00:00<00:00, 11.70it/s]
#     490/499      1.11G    0.01338   0.005963   0.006811         18        320: 100%|##########| 3/3 [00:00<00:00, 12.51it/s]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/2 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  50%|#####     | 1/2 [00:00<00:00,  3.66it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|##########| 2/2 [00:00<00:00,  5.80it/s]
#                    all         40         40      0.997          1      0.995      0.919
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#     491/499      1.11G    0.01182   0.006129   0.004053         36        320:   0%|          | 0/3 [00:00<?, ?it/s]
#     491/499      1.11G    0.01236   0.005388   0.004482         26        320:   0%|          | 0/3 [00:00<?, ?it/s]
#     491/499      1.11G    0.01236   0.005388   0.004482         26        320:  67%|######6   | 2/3 [00:00<00:00, 17.28it/s]
#     491/499      1.11G     0.0121   0.005046   0.003624         15        320:  67%|######6   | 2/3 [00:00<00:00, 17.28it/s]
#     491/499      1.11G     0.0121   0.005046   0.003624         15        320: 100%|##########| 3/3 [00:00<00:00, 14.58it/s]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/2 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  50%|#####     | 1/2 [00:00<00:00,  3.54it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|##########| 2/2 [00:00<00:00,  5.59it/s]
#                    all         40         40      0.997          1      0.995      0.919
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#     492/499      1.11G    0.01267   0.006291   0.003217         33        320:   0%|          | 0/3 [00:00<?, ?it/s]
#     492/499      1.11G    0.01208   0.005662   0.004773         28        320:   0%|          | 0/3 [00:00<?, ?it/s]
#     492/499      1.11G    0.01208   0.005662   0.004773         28        320:  67%|######6   | 2/3 [00:00<00:00, 15.14it/s]
#     492/499      1.11G    0.01203   0.005274   0.003985         13        320:  67%|######6   | 2/3 [00:00<00:00, 15.14it/s]
#     492/499      1.11G    0.01203   0.005274   0.003985         13        320: 100%|##########| 3/3 [00:00<00:00, 14.83it/s]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/2 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  50%|#####     | 1/2 [00:00<00:00,  3.87it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|##########| 2/2 [00:00<00:00,  5.82it/s]
#                    all         40         40      0.997          1      0.995      0.919
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#     493/499      1.11G    0.01348   0.005739   0.004359         33        320:   0%|          | 0/3 [00:00<?, ?it/s]
#     493/499      1.11G    0.01247   0.005108   0.004232         25        320:   0%|          | 0/3 [00:00<?, ?it/s]
#     493/499      1.11G    0.01247   0.005108   0.004232         25        320:  67%|######6   | 2/3 [00:00<00:00, 14.28it/s]
#     493/499      1.11G    0.01293   0.005283   0.006073         17        320:  67%|######6   | 2/3 [00:00<00:00, 14.28it/s]
#     493/499      1.11G    0.01293   0.005283   0.006073         17        320: 100%|##########| 3/3 [00:00<00:00, 14.43it/s]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/2 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  50%|#####     | 1/2 [00:00<00:00,  3.92it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|##########| 2/2 [00:00<00:00,  6.08it/s]
#                    all         40         40      0.997          1      0.995      0.922
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#     494/499      1.11G    0.01159   0.007183   0.005784         36        320:   0%|          | 0/3 [00:00<?, ?it/s]
#     494/499      1.11G    0.01162   0.005781   0.004654         28        320:   0%|          | 0/3 [00:00<?, ?it/s]
#     494/499      1.11G    0.01162   0.005781   0.004654         28        320:  67%|######6   | 2/3 [00:00<00:00, 12.16it/s]
#     494/499      1.11G    0.01166   0.005712   0.003842         15        320:  67%|######6   | 2/3 [00:00<00:00, 12.16it/s]
#     494/499      1.11G    0.01166   0.005712   0.003842         15        320: 100%|##########| 3/3 [00:00<00:00, 12.96it/s]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/2 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  50%|#####     | 1/2 [00:00<00:00,  3.57it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|##########| 2/2 [00:00<00:00,  5.60it/s]
#                    all         40         40      0.997          1      0.995      0.923
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#     495/499      1.11G    0.01223   0.005486   0.005425         33        320:   0%|          | 0/3 [00:00<?, ?it/s]
#     495/499      1.11G    0.01251   0.005739   0.003983         37        320:   0%|          | 0/3 [00:00<?, ?it/s]
#     495/499      1.11G    0.01251   0.005739   0.003983         37        320:  67%|######6   | 2/3 [00:00<00:00, 14.57it/s]
#     495/499      1.11G    0.01197   0.005425    0.00351         13        320:  67%|######6   | 2/3 [00:00<00:00, 14.57it/s]
#     495/499      1.11G    0.01197   0.005425    0.00351         13        320: 100%|##########| 3/3 [00:00<00:00, 13.50it/s]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/2 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  50%|#####     | 1/2 [00:00<00:00,  3.88it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|##########| 2/2 [00:00<00:00,  6.02it/s]
#                    all         40         40      0.997          1      0.995      0.914
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#     496/499      1.11G    0.01146   0.004968   0.002523         31        320:   0%|          | 0/3 [00:00<?, ?it/s]
#     496/499      1.11G    0.01113   0.005093   0.002735         34        320:   0%|          | 0/3 [00:00<?, ?it/s]
#     496/499      1.11G    0.01113   0.005093   0.002735         34        320:  67%|######6   | 2/3 [00:00<00:00, 15.74it/s]
#     496/499      1.11G    0.01191   0.005692   0.002513         17        320:  67%|######6   | 2/3 [00:00<00:00, 15.74it/s]
#     496/499      1.11G    0.01191   0.005692   0.002513         17        320: 100%|##########| 3/3 [00:00<00:00, 15.05it/s]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/2 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  50%|#####     | 1/2 [00:00<00:00,  3.94it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|##########| 2/2 [00:00<00:00,  6.02it/s]
#                    all         40         40      0.997          1      0.995      0.914
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#     497/499      1.11G    0.01008    0.00611   0.002056         33        320:   0%|          | 0/3 [00:00<?, ?it/s]
#     497/499      1.11G    0.01085   0.005849   0.002739         35        320:   0%|          | 0/3 [00:00<?, ?it/s]
#     497/499      1.11G    0.01085   0.005849   0.002739         35        320:  67%|######6   | 2/3 [00:00<00:00, 13.89it/s]
#     497/499      1.11G    0.01209   0.005977   0.003367         14        320:  67%|######6   | 2/3 [00:00<00:00, 13.89it/s]
#     497/499      1.11G    0.01209   0.005977   0.003367         14        320: 100%|##########| 3/3 [00:00<00:00, 14.38it/s]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/2 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  50%|#####     | 1/2 [00:00<00:00,  3.94it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|##########| 2/2 [00:00<00:00,  6.10it/s]
#                    all         40         40      0.997          1      0.995       0.91
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#     498/499      1.11G    0.01089     0.0049   0.003284         34        320:   0%|          | 0/3 [00:00<?, ?it/s]
#     498/499      1.11G    0.01131   0.005699   0.002973         40        320:   0%|          | 0/3 [00:00<?, ?it/s]
#     498/499      1.11G    0.01131   0.005699   0.002973         40        320:  67%|######6   | 2/3 [00:00<00:00, 11.73it/s]
#     498/499      1.11G    0.01121   0.005167   0.002942         12        320:  67%|######6   | 2/3 [00:00<00:00, 11.73it/s]
#     498/499      1.11G    0.01121   0.005167   0.002942         12        320: 100%|##########| 3/3 [00:00<00:00, 12.80it/s]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/2 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  50%|#####     | 1/2 [00:00<00:00,  3.84it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|##########| 2/2 [00:00<00:00,  5.65it/s]
#                    all         40         40      0.997          1      0.995       0.91
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#     499/499      1.11G    0.01121   0.005579   0.003583         36        320:   0%|          | 0/3 [00:00<?, ?it/s]
#     499/499      1.11G    0.01115   0.005292   0.003103         30        320:   0%|          | 0/3 [00:00<?, ?it/s]
#     499/499      1.11G    0.01115   0.005292   0.003103         30        320:  67%|######6   | 2/3 [00:00<00:00, 15.85it/s]
#     499/499      1.11G    0.01123   0.004997   0.002705         12        320:  67%|######6   | 2/3 [00:00<00:00, 15.85it/s]
#     499/499      1.11G    0.01123   0.004997   0.002705         12        320: 100%|##########| 3/3 [00:00<00:00, 13.63it/s]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/2 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  50%|#####     | 1/2 [00:00<00:00,  4.03it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|##########| 2/2 [00:00<00:00,  6.21it/s]
#                    all         40         40      0.997          1      0.995      0.908
#
# 500 epochs completed in 0.111 hours.
# Optimizer stripped from runs\train\exp\weights\last.pt, 14.4MB
# Optimizer stripped from runs\train\exp\weights\best.pt, 14.4MB
#
# Validating runs\train\exp\weights\best.pt...
# Fusing layers...
# Model summary: 157 layers, 7055974 parameters, 0 gradients, 15.9 GFLOPs
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/2 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  50%|#####     | 1/2 [00:00<00:00,  3.10it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|##########| 2/2 [00:00<00:00,  4.41it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|##########| 2/2 [00:00<00:00,  4.14it/s]
#                    all         40         40      0.997          1      0.995      0.923
#                  awake         40         20      0.997          1      0.995      0.933
#                 drowsy         40         20      0.997          1      0.995      0.913
# Results saved to runs\train\exp

# %% [markdown]
# # 8. Load custom model

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path='yolov5/runs/train/exp/weights/best.pt', force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to C:\Users\david/.cache\torch\hub\master.zip
# YOLOv5  2023-4-30 Python-3.9.16 torch-2.0.0 CUDA:0 (NVIDIA GeForce RTX 3080 Ti, 12288MiB)
#
# Fusing layers...
# requirements: C:\Users\david\.cache\torch\hub\requirements.txt not found, check failed.
# Model summary: 157 layers, 7055974 parameters, 0 gradients, 15.9 GFLOPs
# Adding AutoShape...

# %%
detect(1)
